# %% [markdown]
# # <u>Wilcoxon Sign Rank test using scipy

# %% [markdown]
# ***

# %% [markdown]
# **A study is run to evaluate the effectiveness of an exercise program in reducing systolic blood pressure in patients with pre-hypertension (defined as a systolic blood pressure between 120-139 mmHg or a diastolic blood pressure between 80-89 mmHg). A total of 15 patients with pre-hypertension enroll in the study, and their systolic blood pressures are measured. Each patient then participates in an exercise training program where they learn proper techniques and execution of a series of exercises. Patients are instructed to do the exercise program 3 times per week for 6 weeks. After 6 weeks, systolic blood pressures are again measured. The data are shown below.**
# ![image-3.png](attachment:image-3.png)
#
# **Is there is a difference in systolic blood pressures after participating in the exercise program as compared to before?**

# %% [markdown]
# **`Step 1. State the hypotheses.`**
#
# <font face='Comic Sans MS'>Null hypothesis (H0): The median difference is zero versus
#
# <font face='Comic Sans MS'>Alternative hypothesis (H1): The median difference is not zero α=0.05

# %% [markdown]
# **`Step 2. Perform Wilcoxon Sign Rank test statistics`**

# %%
import numpy as np
import pandas as pd

# %%
Before_treatment=[125,132,138,120,125,127,136,139,131,132,135,136,128,127,130]
After_treatment=[118,134,130,124,105,130,130,132,123,128,126,140,135,126,132]

# %%
import matplotlib.pyplot as plt
plt.plot(Before_treatment,marker='o')
plt.plot(After_treatment,marker='o')
plt.legend(['Before treatment','After treatment'])
plt.show()

# %%
import scipy.stats as stats
#perform the Wilcoxon-Signed Rank Test
calculated_value,pvalue=stats.wilcoxon(Before_treatment,After_treatment)

# %%
calculated_value
# Out:
# 31.0

# %%
critical_value=25

# %%
pvalue
# Out:
# 0.10699462890625

# %% [markdown]
# **`Step 3. Conclusion`**
#
# <font face='Comic Sans MS'>As calculated value > critical value, we may accept H0. Therefore we conclude that the median difference in systolic blood pressures is not zero

# %% [markdown]
# <font face='Comic Sans MS'>or
#
# <font face='Comic Sans MS'>As p_value > 0.05, we may accept H0. Therefore we conclude that the median difference in systolic blood pressures is not zero
